# %% [markdown]
# <a href="https://colab.research.google.com/github/PranjaliJain/dialogsum_trained/blob/main/DialogSum_TweetSumm_Pegasus_Batch4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ----- Check if GPU is connected ----- # 
gpu_info = !nvidia-smi -L
gpu_info = "\n".join(gpu_info)
if gpu_info.find("failed") >= 0:
    print("Not connected to a GPU")
else:
    print(gpu_info)
# Out:
# GPU 0: Tesla T4 (UUID: GPU-9d50ace9-76b6-8aa6-d759-b4757c47e4c8)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **DialogSumm**

# %%
# !git clone https://github.com/PranjaliJain/dialogsum_trained.git
# Out:
# fatal: destination path 'dialogsum_trained' already exists and is not an empty directory.

# %%
# %cd /content/dialogsum_trained
# !git stash
#!git pull 
#!git status
# Out:
# /content/dialogsum_trained

# %%
# !pip install datasets
# !pip install transformers
# !pip install rouge_score
# !pip install --user -U nltk
# !pip install sentencepiece
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (2.2.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.11.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.3.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.25.11)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.7.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.18.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /root/.local/lib/python3.7/site-packages (from transformers) (2022.4.24)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.53)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.12.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.25.11)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: rouge_score in /usr/local/lib/python3.7/dist-packages (0.0.4)
# Requirement already satisfied: nltk in /root/.local/lib/python3.7/site-packages (from rouge_score) (3.7)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from rouge_score) (1.0.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from rouge_score) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rouge_score) (1.21.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->rouge_score) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->rouge_score) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk->rouge_score) (4.64.0)
# Requirement already satisfied: regex>=2021.8.3 in /root/.local/lib/python3.7/site-packages (from nltk->rouge_score) (2022.4.24)
# Requirement already satisfied: nltk in /root/.local/lib/python3.7/site-packages (3.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.64.0)
# Requirement already satisfied: regex>=2021.8.3 in /root/.local/lib/python3.7/site-packages (from nltk) (2022.4.24)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 4.9 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.96

# %%
import json
from datasets import load_metric,Dataset,DatasetDict,load_dataset
from transformers import AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer
from transformers import BartForConditionalGeneration, BartTokenizer
from transformers.optimization import Adafactor, AdafactorSchedule
from transformers import PegasusForConditionalGeneration, PegasusTokenizer, Trainer, TrainingArguments
from transformers import AutoTokenizer
# import os
from torch import nn 
import torch

import nltk
nltk.download('punkt')

import sys
from google.colab import drive
import pandas as pd
import numpy as np
import huggingface_hub
import matplotlib.pyplot as plt
import gc
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# ----- Check if GPU is connected ----- # 
gpu_info = !nvidia-smi -L
gpu_info = "\n".join(gpu_info)
if gpu_info.find("failed") >= 0:
    print("Not connected to a GPU")
else:
    print(gpu_info)
# Out:
# GPU 0: Tesla T4 (UUID: GPU-9d50ace9-76b6-8aa6-d759-b4757c47e4c8)

# %%
torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
# model_checkpoint = "facebook/bart-large"
model_name = 'google/pegasus-large'

metric = load_metric("rouge")

TEST_SUMMARY_ID = 1


def transform_single_dialogsumm_file(file):
    data = open(file,"r").readlines()
    result = {"fname":[],"summary":[],"dialogue":[]}
    for i in data:
        d = json.loads(i)
        for j in d.keys():
            if j in result.keys():
                result[j].append(d[j])
    return Dataset.from_dict(result)

def transform_test_file(file):
    data = open(file,"r").readlines()
    result = {"fname":[],"summary%d"%TEST_SUMMARY_ID:[],"dialogue":[]}
    for i in data:
        d = json.loads(i)
        for j in d.keys():
            if j in result.keys():
                result[j].append(d[j])
    
    result["summary"] = result["summary%d"%TEST_SUMMARY_ID]
    return Dataset.from_dict(result)

def transform_dialogsumm_to_huggingface_dataset(train,validation,test):
    train = transform_single_dialogsumm_file(train)
    validation = transform_single_dialogsumm_file(validation)
    test = transform_test_file(test)
    return DatasetDict({"train":train,"validation":validation,"test":test})


def freeze_params(model: nn.Module):
    """Set requires_grad=False for each of model.parameters()"""
    for par in model.parameters():
        par.requires_grad = False

def freeze_embeds(model):
    """Freeze token embeddings and positional embeddings for BART and PEGASUS, just token embeddings for t5."""
    model_type = model.config.model_type
    if model_type == "t5":
        freeze_params(model.shared)
        for d in [model.encoder, model.decoder]:
            freeze_params(d.embed_tokens)
    else:
        freeze_params(model.model.shared)
        for d in [model.model.encoder, model.model.decoder]:
            freeze_params(d.embed_positions)
            freeze_params(d.embed_tokens)

def preprocess_function(examples):
    inputs = [doc for doc in examples["dialogue"]]
    model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True)

    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(examples["summary"], max_length=max_target_length, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip())) for pred in decoded_preds]
    decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) for label in decoded_labels]
    
    result = metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    # Extract a few results
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
    
    # Add mean generated length
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    
    return {k: round(v, 4) for k, v in result.items()}

# %%
raw_datasets = transform_dialogsumm_to_huggingface_dataset("/content/dialogsum_trained/DialogSum_Data/dialogsum.train.jsonl","/content/dialogsum_trained/DialogSum_Data/dialogsum.dev.jsonl","/content/dialogsum_trained/DialogSum_Data/dialogsum.test.jsonl")

torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'


# model = BartForConditionalGeneration.from_pretrained(model_checkpoint)
# tokenizer = BartTokenizer.from_pretrained(model_checkpoint)
tokenizer = PegasusTokenizer.from_pretrained(model_name)
model = PegasusForConditionalGeneration.from_pretrained(model_name)



freeze_embeds(model)

max_input_length = 256
max_target_length = 128

tokenized_datasets = raw_datasets.map(preprocess_function, batched=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-31-cb11806f9905> in <module>()
#       6 # model = BartForConditionalGeneration.from_pretrained(model_checkpoint)
#       7 # tokenizer = BartTokenizer.from_pretrained(model_checkpoint)
# ----> 8 tokenizer = PegasusTokenizer.from_pretrained(model_name)
#       9 model = PegasusForConditionalGeneration.from_pretrained(model_name)
#      10
#
# /usr/local/lib/python3.7/dist-packages/transformers/utils/import_utils.py in __getattr__(cls, key)
#     771         if key.startswith("_"):
#     772             return super().__getattr__(cls, key)
# --> 773         requires_backends(cls, cls._backends)
#     774
#     775
#
# /usr/local/lib/python3.7/dist-packages/transformers/utils/import_utils.py in requires_backends(obj, backends)
#     759     failed = [msg.format(name) for available, msg in checks if not available()]
#     760     if failed:
# --> 761         raise ImportError("".join(failed))
#     762
#     763
#
# ImportError:
# PegasusTokenizer requires the SentencePiece library but it was not found in your environment. Checkout the instructions on the
# installation page of its repo: https://github.com/google/sentencepiece#installation and follow the ones
# that match your environment.
#
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
## use batch_size = 1 to get time around 8 hrs with GPU
## use batch_size = 16 to get time around 4 hrs with GPU - but it goes out of memory
batch_size = 4
args = Seq2SeqTrainingArguments(
    "BART-LARGE-DIALOGSUM",
    evaluation_strategy = "epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=3,
    predict_with_generate=True,
    fp16=True,
    # save_strategy="epoch",
    # metric_for_best_model="eval_rouge1",
    # greater_is_better=True,
    # seed=42,
    # generation_max_length=max_target_length,
    push_to_hub=False,
    #output_dir = '/content/drive/MyDrive/project/results/dialogsumm-bart'
    #logging_dir = '/content/drive/MyDrive/project/results/dialogsumm-bart'
)

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)
optimizer = Adafactor(model.parameters(), scale_parameter=True, relative_step=True, warmup_init=True, lr=None)
lr_scheduler = AdafactorSchedule(optimizer)

trainer = Seq2SeqTrainer(
    model,
    args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    optimizers=(optimizer, lr_scheduler),
    compute_metrics=compute_metrics
)

trainer.train()
# Out:
# Using amp half precision backend
# The following columns in the training set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: summary, fname, dialogue. If summary, fname, dialogue are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 12460
#   Num Epochs = 3
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 9345
#     <div>
#
#       <progress value='9345' max='9345' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9345/9345 1:02:23, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.227800</td>
#       <td>1.132623</td>
#       <td>41.544000</td>
#       <td>21.047700</td>
#       <td>36.502200</td>
#       <td>38.438400</td>
#       <td>19.938000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.015900</td>
#       <td>1.107988</td>
#       <td>43.113500</td>
#       <td>22.944400</td>
#       <td>38.501400</td>
#       <td>40.111800</td>
#       <td>19.876000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.887500</td>
#       <td>1.096485</td>
#       <td>42.263900</td>
#       <td>21.763400</td>
#       <td>37.583600</td>
#       <td>39.225900</td>
#       <td>19.908000</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to BART-LARGE-DIALOGSUM/checkpoint-500
# Configuration saved in BART-LARGE-DIALOGSUM/checkpoint-500/config.json
# Model weights saved in BART-LARGE-DIALOGSUM/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in BART-LARGE-DIALOGSUM/checkpoint-500/tokenizer_config.json
# Special tokens file saved in BART-LARGE-DIALOGSUM/checkpoint-500/special_tokens_map.json
# Saving model checkpoint to BART-LARGE-DIALOGSUM/checkpoint-1000
# Configuration saved in BART-LARGE-DIALOGSUM/checkpoint-1000/config.json
# Model weights saved in BART-LARGE-DIALOGSUM/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in BART-LARGE-DIALOGSUM/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in BART-LARGE-DIALOGSUM/checkpoint-1000/special_tokens_map.json
# Saving model checkpoint to BART-LARGE-DIALOGSUM/checkpoint-1500
# Configuration saved in BART-LARGE-DIALOGSUM/checkpoint-1500/config.json
# Model weights saved in BART-LARGE-DIALOGSUM/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in BART-LARGE-DIALOGSUM/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in BART-LARGE-DIALOGSUM/checkpoint-1500/special_tokens_map.json
# Saving model checkpoint to BART-LARGE-DIALOGSUM/checkpoint-2000
# Configuration saved in BART-LARGE-DIALOGSUM/checkpoint-2000/config.json
# Model weights saved in BART-LARGE-DIALOGSUM/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in BART-LARGE-DIALOGSUM/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in BART-LARGE-DIALOGSUM/checkpoint-2000/special_tokens_map.json
# Deleting older checkpoint [BART-LARGE-DIALOGSUM/checkpoint-500] due to args.save_total_limit
# Saving model checkpoint to BART-LARGE-DIALOGSUM/checkpoint-2500
# Configuration saved in BART-LARGE-DIALOGSUM/checkpoint-2500/config.json
# Model weights saved in BART-LARGE-DIALOGSUM/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in BART-LARGE-DIALOGSUM/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in BART-LARGE-DIALOGSUM/checkpoint-2500/special_tokens_map.json
# Deleting older checkpoint [BART-LARGE-DIALOGSUM/checkpoint-1000] due to args.save_total_limit
# Saving model checkpoint to BART-LARGE-DIALOGSUM/checkpoint-3000
# Configuration saved in BART-LARGE-DIALOGSUM/checkpoint-3000/config.json
# Model weights saved in BART-LARGE-DIALOGSUM/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in BART-LARGE-DIALOGSUM/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in BART-LARGE-DIALOGSUM/checkpoint-3000/special_tokens_map.json
# Deleting older checkpoint [BART-LARGE-DIALOGSUM/checkpoint-1500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: summary, fname, dialogue. If summary, fname, dialogue are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 4
# Saving model checkpoint to BART-LARGE-DIALOGSUM/checkpoint-3500
# Configuration saved in BART-LARGE-DIALOGSUM/checkpoint-3500/config.json
# Model weights saved in BART-LARGE-DIALOGSUM/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in BART-LARGE-DIALOGSUM/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in BART-LARGE-DIALOGSUM/checkpoint-3500/special_tokens_map.json
# Deleting older checkpoint [BART-LARGE-DIALOGSUM/checkpoint-2000] due to args.save_total_limit
# Saving model checkpoint to BART-LARGE-DIALOGSUM/checkpoint-4000
# Configuration saved in BART-LARGE-DIALOGSUM/checkpoint-4000/config.json
# Model weights saved in BART-LARGE-DIALOGSUM/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in BART-LARGE-DIALOGSUM/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in BART-LARGE-DIALOGSUM/checkpoint-4000/special_tokens_map.json
# Deleting older checkpoint [BART-LARGE-DIALOGSUM/checkpoint-2500] due to args.save_total_limit
# Saving model checkpoint to BART-LARGE-DIALOGSUM/checkpoint-4500
# Configuration saved in BART-LARGE-DIALOGSUM/checkpoint-4500/config.json
# Model weights saved in BART-LARGE-DIALOGSUM/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in BART-LARGE-DIALOGSUM/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in BART-LARGE-DIALOGSUM/checkpoint-4500/special_tokens_map.json
# Deleting older checkpoint [BART-LARGE-DIALOGSUM/checkpoint-3000] due to args.save_total_limit
# Saving model checkpoint to BART-LARGE-DIALOGSUM/checkpoint-5000
# Configuration saved in BART-LARGE-DIALOGSUM/checkpoint-5000/config.json
# Model weights saved in BART-LARGE-DIALOGSUM/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in BART-LARGE-DIALOGSUM/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in BART-LARGE-DIALOGSUM/checkpoint-5000/special_tokens_map.json
# Deleting older checkpoint [BART-LARGE-DIALOGSUM/checkpoint-3500] due to args.save_total_limit
# Saving model checkpoint to BART-LARGE-DIALOGSUM/checkpoint-5500
# Configuration saved in BART-LARGE-DIALOGSUM/checkpoint-5500/config.json
# Model weights saved in BART-LARGE-DIALOGSUM/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in BART-LARGE-DIALOGSUM/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in BART-LARGE-DIALOGSUM/checkpoint-5500/special_tokens_map.json
# Deleting older checkpoint [BART-LARGE-DIALOGSUM/checkpoint-4000] due to args.save_total_limit
# Saving model checkpoint to BART-LARGE-DIALOGSUM/checkpoint-6000
# Configuration saved in BART-LARGE-DIALOGSUM/checkpoint-6000/config.json
# Model weights saved in BART-LARGE-DIALOGSUM/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in BART-LARGE-DIALOGSUM/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in BART-LARGE-DIALOGSUM/checkpoint-6000/special_tokens_map.json
# Deleting older checkpoint [BART-LARGE-DIALOGSUM/checkpoint-4500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: summary, fname, dialogue. If summary, fname, dialogue are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 4
# Saving model checkpoint to BART-LARGE-DIALOGSUM/checkpoint-6500
# Configuration saved in BART-LARGE-DIALOGSUM/checkpoint-6500/config.json
# Model weights saved in BART-LARGE-DIALOGSUM/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in BART-LARGE-DIALOGSUM/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in BART-LARGE-DIALOGSUM/checkpoint-6500/special_tokens_map.json
# Deleting older checkpoint [BART-LARGE-DIALOGSUM/checkpoint-5000] due to args.save_total_limit
# Saving model checkpoint to BART-LARGE-DIALOGSUM/checkpoint-7000
# Configuration saved in BART-LARGE-DIALOGSUM/checkpoint-7000/config.json
# Model weights saved in BART-LARGE-DIALOGSUM/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in BART-LARGE-DIALOGSUM/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in BART-LARGE-DIALOGSUM/checkpoint-7000/special_tokens_map.json
# Deleting older checkpoint [BART-LARGE-DIALOGSUM/checkpoint-5500] due to args.save_total_limit
# Saving model checkpoint to BART-LARGE-DIALOGSUM/checkpoint-7500
# Configuration saved in BART-LARGE-DIALOGSUM/checkpoint-7500/config.json
# Model weights saved in BART-LARGE-DIALOGSUM/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in BART-LARGE-DIALOGSUM/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in BART-LARGE-DIALOGSUM/checkpoint-7500/special_tokens_map.json
# Deleting older checkpoint [BART-LARGE-DIALOGSUM/checkpoint-6000] due to args.save_total_limit
# Saving model checkpoint to BART-LARGE-DIALOGSUM/checkpoint-8000
# Configuration saved in BART-LARGE-DIALOGSUM/checkpoint-8000/config.json
# Model weights saved in BART-LARGE-DIALOGSUM/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in BART-LARGE-DIALOGSUM/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in BART-LARGE-DIALOGSUM/checkpoint-8000/special_tokens_map.json
# Deleting older checkpoint [BART-LARGE-DIALOGSUM/checkpoint-6500] due to args.save_total_limit
# Saving model checkpoint to BART-LARGE-DIALOGSUM/checkpoint-8500
# Configuration saved in BART-LARGE-DIALOGSUM/checkpoint-8500/config.json
# Model weights saved in BART-LARGE-DIALOGSUM/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in BART-LARGE-DIALOGSUM/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in BART-LARGE-DIALOGSUM/checkpoint-8500/special_tokens_map.json
# Deleting older checkpoint [BART-LARGE-DIALOGSUM/checkpoint-7000] due to args.save_total_limit
# Saving model checkpoint to BART-LARGE-DIALOGSUM/checkpoint-9000
# Configuration saved in BART-LARGE-DIALOGSUM/checkpoint-9000/config.json
# Model weights saved in BART-LARGE-DIALOGSUM/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in BART-LARGE-DIALOGSUM/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in BART-LARGE-DIALOGSUM/checkpoint-9000/special_tokens_map.json
# Deleting older checkpoint [BART-LARGE-DIALOGSUM/checkpoint-7500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: summary, fname, dialogue. If summary, fname, dialogue are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 4
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=9345, training_loss=1.0795598094893242, metrics={'train_runtime': 3744.2886, 'train_samples_per_second': 9.983, 'train_steps_per_second': 2.496, 'total_flos': 1.9283523178266624e+16, 'train_loss': 1.0795598094893242, 'epoch': 3.0})

# %%
out = trainer.predict(tokenized_datasets["test"],num_beams=5)
predictions, labels ,metric= out
print(metric)
# Out:
# The following columns in the test set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: summary, summary1, fname, dialogue. If summary, summary1, fname, dialogue are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 500
#   Batch size = 4
#     <div>
#
#       <progress value='125' max='125' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [125/125 01:10]
#     </div>
# {'test_loss': 1.3360599279403687, 'test_rouge1': 41.5981, 'test_rouge2': 18.7302, 'test_rougeL': 35.8956, 'test_rougeLsum': 37.8259, 'test_gen_len': 19.866, 'test_runtime': 73.2878, 'test_samples_per_second': 6.822, 'test_steps_per_second': 1.706}

# %%
decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # Rouge expects a newline after e ach sentence
decoded_preds = [" ".join(nltk.sent_tokenize(pred.strip())) for pred in decoded_preds]
decoded_labels = [" ".join(nltk.sent_tokenize(label.strip())) for label in decoded_labels]

# %%
# output summaries on test set
with open("test_output.txt","w") as f: 
    for i in decoded_preds:
        print(i)
        f.write(i.replace("\n","")+"\n")
# Out:
# #Person1# asks Ms. Dawson to take a dictation for him
# #Person2# got stuck in traffic again. #Person1# suggests #Person
# #Person1# tells Kate Masha and Hero are getting divorced. Kate is surprised
# #Person1# wishes Brian a happy birthday and dances with him at the party
# #Person1# and #Person2# are in the Olympic stadium. #Person
# #Person1# tells #Person2# #Person3# is quitting
# #Person2# feels itchy and #Person1#Person3#
# #Person2# checks out and finds the bill has been added to someone else's
# #Person1# asks Steven for help because his wife is going to divorce him.
# #Person2# thinks of Abraham Lincoln as a man or woman of sound character.
# #Person1# tells #Person2# the north of China are experiencing severe sand
# Francis gets a remote car as a birthday gift from #Person2#. Francis
# Tony tells Steven he got caught cheating and feels ashamed. Steven advises him to study hard
# #Person1# is in a hurry to catch the nine-thirty train.
# #Person1# asks #Person2# for advice on adjusting life. #Person
# #Person1# invites #Person2# to Ruojia's party
# #Person1# tells #Person2# to pull on the strip and peel
# Mike tells #Person1# his sister is tall and pretty but not as clever as
# #Person1# has a headache and #Person2# thinks #Person1
# #Person2# wants to buy a new mobile phone with a camera and MP3
# Frank tells Judy he will be working for the Post Office because of its excellent health insurance
# #Person1# interviews #Person2#. #Person3# tells #Person
# #Person1# wants the steak to be medium-rare but #Person2
# #Person1# congratulates Tom on winning the Nobel Prize.
# #Person2# tells #Person1# #Person3#'s
# #Person2# usually drinks at least 10 drinks at night. #Person1
# #Person1# asks May to help her mother prepare for the picnic.
# Muriel Douglas and James meet each other for the first time. They talk about their
# #Person1# wants to withdraw 10000 USD to the World Wildlife Foundation from the
# #Person2# tells #Person1# #Person3# is outgoing
# Mr. Polly wants to buy a bottle of soft drink from #Person1#
# Monica calls Francis to arrange a time to work on the financial report. Francis agrees
# #Person2# introduces the interview class to #Person1# and gives #Person
# #Person1# cuts Mike's lines because Mike is acting hurt and sad
# #Person1# comes over to say hello to Mrs. Todd. Mrs.
# Bill tells #Person1# he's tired because he works until around ten every night
# Cleo doesn't want to go to the demonstration to stop the spread of nuclear weapons
# #Person1# and #Person2# think it's partly #Person1
# Mark wants to borrow Maggie's notes for history because he works in supermarket from 7 to
# #Person2# wants to enroll in Professor Turner's Advanced Geology course
# #Person1# bought a pendant in #Person2#'s
# #Person1# is trying to have a conversation with #Person2# about #
# #Person1# suggests #Person2# become a TV news director but #Person
# #Person2# is bored because there are boring people giving boring speeches. #Person
# Sarah and her husband can't afford a house near their company. #Person1#
# Mark Leach, an information officer at the Britain Business Center, tells #Person1
# Lin Fang tells Lucy that English is Lin Fang's favorite subject while math is Lucy's
# James helps Mrs. Thomas to clean up the leaves and take her dog Oscar for a
# #Person1# thinks spring is finally here but it's still cold at night.
# #Person1# cuts Mike's lines because Mike is acting hurt and sad
# #Person1# takes a taxi and asks #Person2# to fast the speed
# #Person1# is broke and has to catch another bus. #Person2#
# #Person2# tells #Person1# it takes 15 minutes' drive to downtown
# #Person1# tells #Person2# Lulu broke up with Vic and asked
# Dave Thomson wants to speak to Jim but Sally says Jim isn't available. Dave will
# #Person2# tells #Person1# how to get to City Hall
# #Person1# can't find the passport. #Person2# asks #
# Leah calls Nathaniel to tell him Ms. Collins will not be able to call him
# #Person1# and #Person2# are talking about Sarah who would marry no
# #Person1# and #Person2# are at a party. #Person1
# Jack tells #Person1# he likes his poli-sci class and his favorite
# #Person1# and #Person2# are talking about the weather in Beijing.
# #Person1# invites #Person2# to go to the movies, but #
# Adam shows #Person1# around the school and introduces the tallest building, the library
# #Person1# tells #Person2# that #Person3# is pregnant and
# #Person1# and #Person2# think John may fall for a girl.
# #Person1# suggests #Person2# add a painting program and upgrade the hardware
# #Person2# tells #Person1# she is flying in from China and
# #Person1#'s weight has gone up again. #Person2#
# James wants a dinning room but it's not available now. #Person1#
# #Person2# tells #Person1# about the size of the plant, the
# Rebecca tells #Person1# her first job was as an intern for a local
# #Person1# needs to buy something for the posters. #Person2# suggests
# Mary is tired because she goes to the personnel market every day. #Person1#
# #Person2# is figuring out #Person1#'s budget. #
# Jane is going to the hospital to see Susan. Henry tells her a number 13 bus
# #Person1# wants to talk to #Person2# about the sales projections.
# #Person2# recommends a personal tour guide service called 'A friend in New York
# #Person2# tells #Person1# about the company and #Person
# #Person1# wants to sign the agreement but it hasn't been fully prepared.
# #Person1# calls ABC Rent-a-car Company to report a car accident
# #Person2# tells #Person1# the way to the school clinic.
# #Person2# asks #Person1# to change her room because the baggage elevator
# #Person1# drives #Person2# to the Beijing hotel. #Person
# #Person2# shows #Person1# the way to Liu Ichang,
# #Person2#'s computer doesn't work well. #Person1# suggests
# #Person2# is looking for a gift for his mother. #Person1#
# Ms. Ross and Mr. Fisher greet each other and talk about their business.
# #Person2# tells #Person1# the main differences between this country and #
# #Person2#'s thinking about going on the voyage to the Caribbean Sea
# #Person1# and #Person2# are going to take some fruit
# #Person2# helps #Person1# rent an economy car tomorrow morning.
# #Person1# and #Person2# are talking about smiling. #Person1
# #Person1# and #Person2# are talking about the good news
# #Person2# tells #Person1# that #Person3# lost #Person
# Lin thanks Steven for the meal and asks Steven about tipping in China. Steven tells Lin
# Bill tells #Person1# that he made a move today and introduces his roommate to
# #Person2# helps Tom Wilson to pay the bill by credit card.
# Carol calls Susan but Susan is taking a shower. #Person1# tells Susan
# #Person1# thinks she knows #Person2# from somewhere, but #Person
# #Person1# and #Person2# are talking about the election of
# #Person2# teaches #Person1# how to use the ATM.
# Susan Miller calls John to ask where the memo about office procedures is.
# #Person1# invites Lily to take part in their picnic this weekend.
# #Person2# has been invited to a Chinese feast. #Person2
# Mary spends a lot of time watching movies in her spare time. Frank always watches movies
# #Person2# tells #Person1# that #Person3# thought about joining
# #Person1# apologizes to Mr. Wilson for the mistakes in goods
# #Person2# tells #Person1# about the robbery and will come to the
# #Person2# tells #Person1# they're on their own tonight because their
# #Person1# tells Carol that he's going to go on a diet
# Karen Huang wants to register for Comp Lit 287 but the computer won't let her
# #Person1# and #Person2# decide to walk together because #Person1
# Jack got rid of the clunker and gives Daisy a ride in his new car.
# #Person1# asks #Person2# the exact time when the big fire broke
# #Person2# wants to pay by credit card, but #Person1# says
# #Person2# wants to get the car washed. #Person1# recommends a
# Harry tells #Person1# he may travel by sea this year because his wife worries
# Johnson is a new member and asks #Person2# how to get started using the
# #Person1# and #Person2# are out of a job.
# #Person1# asks #Person2# to give the puppies a bath and
# #Person1# asks Ayden to loan some cash to get through the weekend
# #Person2# tells #Person1# that working in a charity organization
# #Person2# asks #Person1# to let him know when #Person
# #Person2# recommends Moutan and Roast Beijing Duck to #Person1
# Angela calls Dan to remind him that his friend is getting married next week. Dan
# #Person1# and #Person2# are having dessert. #Person
# Mr. Smith tells #Person1# he went to Yale University and worked in a
# #Person1# wants to buy a Barbie for his niece. #Person
# #Person1# helps #Person2# buy a pair of sport shoes.
# #Person1# wants to go to the science museum but can't make heads or
# Simon tells #Person1# he hasn't stopped work completely because he's on a
# #Person1# persuades Rocky to dance with a woman but Rocky refuses because he
# #Person1# and #Person2# talk about the heavy storm last night.
# #Person2# doesn't want to watch TV because it's boring. #Person
# Ben is nervous about tomorrow's lessons. #Person1# tells him about the schedule
# Adam's knee feels better today. #Person1# asks Adam to take it
# #Person1# asks #Person2# to print up a copy for #Person
# #Person1# asks #Person2# to help put the curtain up.
# #Person1# asks Jack to check the calendar to know the best weekend for
# #Person1# forgives #Person2# for not calling because #Person
# #Person2#'s worried about his daughter who can't decide about college
# #Person1# is worried about losing the job because of a big mistake. #
# #Person2# tells #Person1# that #Person3#'s friend
# #Person2# tells #Person1# she's getting sick. #Person
# Mr. Faber calls York Hotel to book a double room for 3 nights
# #Person2# recommends West Derby to #Person1# because it's closer to
# #Person1# blames #Person2# for the traffic accident. #Person
# Dan tells Darlene that the order of 100 computers has been delayed for 2 days
# #Person1# asks #Person2# about the founding date of the Washington Post
# #Person2# can't send out the e-mail. #Person1#
# #Person1# and #Person2# enjoyed their weekend.
# #Person1# wants to get a bite to eat. #Person2#
# Marry tells Tom they had decided to offer the sales position to someone else. Tom
# #Person1# warns #Person2# not to call again or #Person1
# #Person2# wants to be a music teacher because #Person1# specialized in
# #Person2# tells #Person1# that he met the girl living
# #Person1# and #Person2# are talking about Mirella's
# #Person2# is going to set up #Person1#'s
# Peter tells Kate he was online the whole night and needs a rest.
# #Person1# and #Person2# think ships and boats are no longer so
# Fanny tells Andy she had a bad dream last night because she was chased
# #Person1# and Ernie are going to start a band together. #Person
# #Person1# invites #Person2# to a jazz club and an evening river
# #Person1# buys a nice dress with #Person2#'s assistance.
# #Person1# asks Mr. Blake to send over the training manuals. Mr.
# #Person2# tells David #Person1# is going to Salt Lake City
# #Person2# reminds #Person1# to board the plane and asks #Person
# #Person2# tells #Person1# the busiest street of the city is
# #Person1# and #Person2# are watching a programme about Islam. #
# #Person2# tells #Person1# how to get to the central department stall
# #Person1# invites #Person2# to go to London for a couple of
# Tom didn't enjoy his lunch because the chicken was underdone and the food station was
# #Person1# helps #Person2# order lemonade, barbeque wings
# #Person1# helps #Person2# order a double cheeseburger, some
# #Person2# makes #Person1# some muffins for breakfast. #Person
# #Person2# tells #Person1# the location of the Grand Hotel.
# #Person1# wants to take a picture of #Person2# to show #
# #Person1# tells #Person2# they are full up for tomorrow and suggests
# #Person2# has applied for a student visa to go to the United States
# Anne tells #Person2# she didn't have a good time last time because she
# Mary tells #Person1# online shopping is convenient and time-saving. #Person
# #Person1# asks #Person2# some questions about American-styled accounting
# Jane invites Peter to go to Xi'an in the summer. Peter is interested and
# #Person2# wants to rent some movies for his daughter. #Person1#
# #Person2# asks #Person1# to sign Mr. Lee's parcel
# #Person2# tells #Person1# the airport is closed and they
# #Person1# wants to repay the favor to #Person2#. #Person
# #Person2# has been having a hard time sleeping lately because #Person2
# #Person1# wants to give their kitchen the works. #Person2# thinks
# Walter thinks Professor Wood is brilliant while Sterling thinks he's absent-minded.
# #Person1# wants to get the test results from the other day. #Person
# Miss Eliza asks Martin about his preparations for the coming exams. Martin tells Miss El
# #Person1# wants to mail a package to Korea first class. #Person2
# #Person1# can't find the cellphone in the hotel room. Linda
# #Person1# comes to #Person2#'s city for tourism
# #Person1# wants to take a break from studying. #Person2# wants
# #Person2# tells Mary about the experience of being chased by a dog
# #Person1# asks #Person2# some questions about the job. #Person
# #Person1# wants to open a current account. #Person2# tells #
# #Person1# wants to try some real Chinese cuisine. #Person2# recommends
# #Person2# tells #Person1# that they agree to the price but
# #Person1# has broken the reading lamp and asks #Person2# to bring
# #Person1# introduces the 2006 fiscal year marketing plan to #Person2#.
# #Person2# is going to travel around Europe during the holiday. #Person1
# Jimmy Fox made a reservation for a mid-size vehicle. #Person2# tells
# #Person1# wants to play the card games. #Person2# asks #
# Ann tells Mr. Jones about the meetings he has this week and introduces Ms. Von
# #Person2# is preparing for a geography class. #Person1# and #
# #Person2# wants to change the room because the smell of smoke is too strong
# #Person1# warns Bill not to touch the wet paint and asks him to be
# Ella and Ben have a good time and Ella asks Ben for his phone number
# Bill tells Jim Dick is better now and can come back to work.
# #Person2# has worked overtime for two weeks without a break. #Person1
# Lisa tells #Person1# her husband Mark has been seeing someone else for two months
# #Person2# tells #Person1# the doctor told #Person2
# #Person1# wants to leave but #Person2# insists on #Person1
# #Person2# tells #Person1# how to use the library and
# #Person1# and #Person2# are enjoying the nice spring day. They
# #Person1# confiscates #Person2#'s camera and tells #Person
# #Person1# tells #Person2# the interest rate depends on how long #
# Monica's presentation at the meeting was successful. #Person1# congratulates her
# Tom invites #Person1# to go for a run in the morning. #Person
# #Person2# tells #Person1# the Japanese Restaurant is open until 10
# #Person1# invites Mr. Simpson to lunch on Thursday. Mr.
# #Person1# wants to take a date to a restaurant. #Person2#
# #Person2# helps #Person1# pay for food and drinks.
# #Person1# and #Person2# talk about the popular sports in their
# #Person1# helps #Person2# to make a flight reservation for the twenty
# #Person1# tells #Person2# #Person3#'s
# #Person1# invites #Person2# to go to Australia.
# Laura is off to the gym because she wants to stay in shape. #Person1
# #Person2# tells #Person1# #Person3# was born
# #Person2# thinks #Person1#'s new suit reminds #Person2
# Ann is broadcasting from university radio and Robin, president of the Martha Bicycle Club, is
# #Person1# helps #Person2# order a Compari, a Singer,
# #Person1# invites Gregory to lunch. #Person2##Person2
# #Person1# wants to find information on World War Two. #Person2#
# #Person2# is new here and doesn't know where to begin. #
# #Person1# wants to park on campus. #Person2# tells #Person
# Emily asks Susan some questions about her paycheck. Susan explains to Emily the FICA,
# #Person2# teaches #Person1# how to buy something from a vending machine
# #Person2# tells #Person1# that #Person3# is going to
# Kate has been saving up money to buy some new furniture and do some redecor
# #Person2# gives Bill a daily exercise schedule but Bill doesn't know
# Marquet suggests #Person1# enroll in the science course and recommends a good introductory
# Tim tells #Person1# about his project and how to lead a greener life
# #Person1# feels tired because everything has been going wrong lately. #Person1
# Sue is not in the cake because she is on a diet to avoid being allergic
# #Person2# buys a T-shirt and a skirt with #Person1#
# #Person1# comes to pick up the tickets. #Person2#
# #Person2# tells Yi-jun about the family reunions on Easter
# #Person1# tells #Person2# their son has some bad habits now
# #Person1# tells #Person2# Julie and Alex are getting married. #
# #Person2# doesn't know where to get the ballot. #Person1#
# #Person1# tells #Person2# their company is going to do some cut
# #Person2# has been watching a Chinese TV series called Chinese-Style Div
# Judy shows #Person1# the list of their financial budget and tells #Person
# #Person1# tells #Person2# Mary got married yesterday. #Person
# #Person2# lost the wallet and borrows 50 dollars from #Person
# #Person1# tells #Person2# that Murphy Music and U-Tunes
# Joe wasn't too impressed with Tom's new assistant because she never says 'hello'
# Sarah tells #Person1# she is upset because the meeting didn't go very well
# #Person1# and #Person2# are watching a program about islam.
# Ted asks Mike if Jenny is coming with them. Mike tells him someone has a crush
# #Person2# usually calms down first and thinks about the reason that caused #
# #Person1# asks #Person2# about the family in New Zealand. #
# #Person1# congratulates Mr. Stuart on winning the city marathon.
# #Person2# is picking out some presents for his children and wife. #Person
# Hong suggests #Person1# use a local SIM card to call back to the UK
# #Person2# tells Mr. Brown that #Person1# is paid
# #Person1# and #Person2# talk about Barry and his brother Paul
# #Person1# wants to buy a medium-sized house with at least 3
# Mr. Grant asks #Person2# to leave the samples with him and
# #Person2# tells #Person1# how to go to Sons from PHS
# Mr. Lee gives Mrs. Word a lift home and asks her to hold
# #Person1# checks #Person2#'s arm and asks #Person
# #Person2# lost his card. Shelley from IBA's Client Services
# #Person1#'s going to take a nap. #Person2#
# #Person1# helps #Person2# order Chinese food, bean milk, two
# #Person1# and #Person2# get the table wares and stand in
# #Person1# asks Lucy to sing but Lucy wants to listen. #Person1
# #Person2# thinks home video players will replace movie theatres and force them out
# #Person2# wants to buy a light cotton dress. #Person1# recommends
# #Person1# asks #Person2# for #Person3#'
# #Person1# and #Person2# will go to Mike's birthday party
# #Person1# wants to send a package by first-class mail. #Person
# #Person1# and #Person2# talk about the earthquake in Wenchuan
# #Person1# and #Person2# talk about the miserable weather. #Person
# #Person1# and #Person2# will go to the Olympic souvenir store
# #Person1# wants to purchase a 16' pan. #Person2# recommends
# #Person1# and #Person2# will catch a ride after work.
# Mr. Becker shows #Person1# around his offices and tells #Person
# Pete and Henry meet each other for the first time and introduce themselves to
# Julie tells Mr. Jones she's been ill since last Sunday because she had food
# Mike comes to #Person1#'s house to get some drinks for some friends
# #Person1# and #Person2# meet each other at the station
# #Person1# interviews #Person2# and asks about the job. #
# Jimmy tells Amy he came home very late yesterday evening because Jennie and Bill invited him
# #Person1# invites Peter to have tea, but Peter has to water the garden
# #Person1# and #Person2# will call an emergency meeting when Ken gets
# #Person2# buys some stamps for a registered letter with #Person1#'
# Mr. Smith has a nasty infection. The doctor prescribes some antibiotics and
# #Person2# wants to take some Chinese arts and crafts home. #Person1
# #Person1# introduces the famous Eiffel Tower to #Person2#.
# Brian tells #Person1# he learned English in college and has been in the U
# #Person2# is worried about #Person1#'s friend who hasn't
# #Person1# warns #Person2# not to do what #Person
# #Person1# and #Person2# think John may fall for a girl.
# #Person1# and #Person2# are talking about the history of London
# Daniel tells #Person2# he likes science because he can learn more about the world
# #Person1# thanks #Person2# for organizing a great baby shower. #
# #Person1# wants to go to China for sight-seeing. #Person
# Tim and Karren say goodbye to each other.
# #Person2# tells #Person1# that Michael let #Person2
# #Person2# can speak English and French well. #Person1# asks #
# #Person1# calls Tyler residence and leaves a message for Naomi's sister
# #Person1# wants to book a flight to New York but #Person2#
# #Person1# and #Person2# are going to Burger Queen for lunch.
# #Person1# asks #Person2# to pay the excess luggage charge
# #Person1#'s parched. #Person2# suggests #Person1
# Wang Miao from AB company calls Manager Liang to tell him that Mr. Green
# #Person1# buys a pair of enameled leather shoes with #Person2
# Benjamin tells #Person1# he doesn't know how to write a project report
# Marty helps #Person2# order a medium pizza with pepperoni, olives
# #Person1# orders prawn cocktail, tomato soup, and mineral water for dinner
# #Person1# tells #Person2# the house has a nice living room,
# #Person2# complains to #Person1# that the stereo #Person2
# #Person1# makes the dormitory deposit for next year. #Person2#
# #Person1# and #Person2# are going through secondhand bookstores.
# #Person1# shows #Person2# the way to Beijing Tasty Restaurant
# #Person2# tells #Person1# how to send a certificate and a watch
# Tom writes a letter to Sally and John and asks them to call him when they arrive
# #Person1#'s frustrated because #Person2# can't get access to
# #Person1# and #Person2# think it's a beautiful day. They
# #Person1# wants to find some general information on computers. #Person2#
# #Person2# comes to the French Garden Restaurant and orders a bottle of water and
# #Person1# helps #Person2# order lemonade, barbeque wings
# #Person1# helps #Person2# order some water, coffee, and dessert
# #Person2# would say yes if Eric asked her out on a date. #
# #Person1# shows Jack the picture of #Person2#'s
# #Person1# tells #Person2# Aunt Jane bought Tom a new bike
# #Person2# tries on a skirt and thinks it's cute but expensive.
# #Person2# tells #Person1# about the history of the city. #
# #Person1# and #Person2# talk about the environmental problems in the world
# Dennis tells #Person2# he pretended to be a 16-year-old
# Nathan tells his mom he's going to Chicago for his practice. Nathan
# #Person1# helps #Person2# rent a Toyota Carola for 3 days
# #Person2# recommends #Person1# to visit the UN building, Broadway,
# #Person1# asks #Person2# to develop the roll of film.
# #Person1#'s flight has been delayed due to heavy rain. #Person
# #Person2# shows #Person1# the way to Peking University
# #Person1# and #Person2# are reading the newspaper. #Person
# #Person1# hates computer games because they are too violent. #Person2#
# #Person1# suggests going for a few beers after dinner, but Jim
# #Person1# and #Person2# order the chicken feet and a bottle
# #Person2# tells #Person1# that #Person3# guided a few
# #Person1# helps Jack to fill up the forms for his reservation.
# Jill calls Mark to ask why he didn't come to work today. Mark tells
# #Person1# invites #Person2# to go to the theatre but #Person
# #Person2# tells #Person1# Cal Ripen hit a home run
# #Person1# helps #Person2# to get set up. #Person
# #Person2# tells #Person1# #Person3#'s
# #Person1# loves going to art galleries, particularly when one is holding an
# #Person2# wants to return a book and check out a video. #Person
# #Person1# tells #Person2# there are 10 frames in a bowling game
# #Person2# received some leaflets in the post from #Person1#. #
# #Person1# is checking out and needs a place to put his luggage. #
# #Person1# tells #Person2# about the charge of the buffet
# #Person2# wants some info about suitable loans. #Person1# tells #
# #Person1# asks #Person2# for some English songs. #Person
# #Person1# interviews #Person2# who has impressive writing experience. #Person
# #Person1# wants to ask for the results of the interview. Jack suggests
# #Person1# comes to #Person2#'s house to have a look
# #Person2# tells #Person1# she can leave her baggage in the storage
# Brandon tells #Person1# about a new Web site that helps people improve their writing
# #Person2# tells #Person1# the headmaster may build a new lab
# Kate is happy she started carrying the credit card because it makes it easy to spend money
# #Person1# tells Mr. Smith about the visit to a village planned for tomorrow
# #Person1# asks Vet about how to deal with stress and depression,
# #Person2# tells #Person1# #Person3# has loved
# Tom tells #Person1# he started a web-designed company in high school and
# #Person1# interviews Detective Chief Superintendent John Day about the death of a man
# Sherry tells Bob she will visit Quebec next summer to go to a friend's wedding
# Tom invites Jane to go swimming at the Student Center, but Jane has a paper due
# #Person2# suggests #Person1# start taking the medicine three times a day
# #Person1# asks Fred to lend some money because the phone is out of service
# #Person1#'s handwriting is still bad. #Person2# encourages #
# #Person2# is curling eyelashes. #Person1# is afraid of
# #Person1# tells #Person2# about the driving courses during the summer and
# Tina tells #Person1# she has been learning the piano for 8 years from
# #Person1# interviews #Person2#. #Person3# thinks #Person
# Stephanie has a bad headache. George suggests she hand in the report on Friday
# #Person1# invites David to go skating but David wants to stay in New York
# Bob visited a friend and went to a dance party last weekend. #Person1#
# #Person1# borrows $50 from #Person2# because #Person1
# #Person2# wants to borrow a jacket and a tie from #Person1#
# #Person2# tells #Person1# the children enjoyed the holiday camp and
# #Person1#'s dad asks many questions about admission requirements of college. #
# Kalina calls Professor Clark to tell him she needs to miss a few days of school
# #Person2# complains to #Person1# that the house owner takes too long
# #Person1# helps #Person2# to collect an Export L/C from
# Myrdal lost her purse and Charlie asks her to go back to the hot
# #Person1# has been washing the dishes for over a week. #Person2
# #Person1# wants to know if #Person2# loves her. #Person
# #Person1# and #Person2# think unemployment causes social problems.
# #Person1# invites #Person2# to go shopping together next Saturday to
# #Person1# and #Person2# are going to a nightclub. #Person
# #Person1# wants to have a farm. #Person2# thinks
# #Person1# orders two pints of Heineken and half a pint of
# Mary tells #Person1# she had a big argument with Ann last night because Ann
# #Person2# tells #Person1# where to buy cigarettes and where to
# Catherine tells Tom the movie Fast Food Nation reveals the dark side of the all-
# #Person1# tells #Person2# the bus goes down Fifth Avenue as far
# #Person2# was in Beijing for the terrorist attacks on 9-11. #
# Karl and his wife are moving in next door to Chuck Jones. Karl tells Chuck
# #Person2# orders a boiled egg with toast and orange juice with #Person1
# #Person1# wants to go to bed but Steven wants to finish the household budget
# #Person1# invites Jane to meet before next week's meeting. Jane agrees.
# #Person2# wants to buy a gift for his girlfriend. #Person1#
# #Person1# wants to trade in the old Ford Pinto. #Person2
# #Person1# calls Ballam to offer him the position of computer engineer. Ball
# #Person1# tells #Person2# about the benefits of the agreement and #
# #Person1#'s hungry again. #Person2# suggests #Person1
# #Person2# helps #Person1# to have blood drawn to check #Person
# Steven calls Mr. Sellers to ask him how to fix the power failure. Mr
# Paula tells #Person2# the landlord Ms. Connors is threatening
# #Person1# and #Person2# are complaining about the broken air conditioning
# #Person1# got laid off and is looking for work. #Person
# #Person2# tells #Person1# their relationship with their boss.
# #Person1# asks Mr. Tang about his working experience and language proficiency.
# #Person2# wants to buy a watch. #Person1# shows #Person
# Tom calls Sara to ask her to take care of his daughter Maria who has a fever
# Amy tells #Person1# about her first job as a secretary to the General Manager
# #Person1# tells Andrew that he has put on a ton of weight since
# Greg Sonders from Brown College calls Mary to ask about her interest in college sports
# #Person1# takes a taxi to the railway station. #Person2#
# Brian tells #Person1# he learned English in college and has been in the U
# #Person2# comes to #Person1# for annual physical examination. #Person
# #Person1# tells #Person2# that if they won the P
# #Person1#'s freaking out because he's not ready for marriage
# #Person1# wants to get some business cards printed up. #Person2#
# Brian will pick #Person1# up at 6:00 and will take #Person
# Paul is still having Thanksgiving dinner at #Person1#Person2#'
# John asks Susan for help this weekend because his cousin is coming on Thursday and Friday.
# #Person1# shows Ben the information about the evening classes #Person1
# #Person1# and #Person2# are discussing where to eat. They finally
# Gene tells #Person1# that he will take the driving test this Saturday because he
# #Person1# buys a pen with #Person2#'s assistance.
# #Person2# tells #Person1# their company's fundraiser went well. They
# #Person2# tells #Person1# the way to the Peak Tram
# #Person2# wants to see some traditional Chinese arts and crafts. #Person1
# #Person2# tells #Person1# the external factors have great impact on the
# #Person1# and #Person2# will start working on the project at around
# #Person2# wants to stay in #Person1#'s cry for just
# #Person2# orders a beef-burger, a French fry, a milk
# #Person1# and #Person2# are watching the lanterns during the Lantern
# #Person1# tells Tina #Person2# has successfully passed the first two
# Tim and Karren say goodbye to each other.
# #Person1# tells #Person2# they're having a department meeting at 10
# #Person1# asks #Person2# how to use the buttons. #Person
# #Person1# asks #Person2# for some advice on books for killing time
# #Person1# asks #Person2# to teach #Person3#'
# #Person2# helps #Person1# pick up the ticket.
# #Person1# invites #Person2# to make dinner together, but #Person
# #Person2# tells #Person1# how to use the two phones on the
# #Person2# tells #Person1# EDD has special services to help #
# #Person1# is considering buying a second-hand computer. Tom tells #Person
# Morgan tells #Person1# many Chinese people take their leftover food home from a restaurant
# Harry is mad because he bought a bag on the spot without bargaining. #Person2
# #Person1# asks #Person2# about the English proficiency of #
# #Person2# wants to open a new account. #Person1# helps #
# #Person2# tells #Person1# how to get special discount coupons. #
# Mrs. Robinson thanks Steve for looking after Johnny and cleaning the kitchen.
# #Person2# lost his train ticket. #Person1# helps #Person2
# Ann tells #Person1# she didn't have much time to see New York because
# Mary tells Tom she can't go to John's party tonight because she has found a
# Harry tells #Person1# he was almost hit by a car when crossing the street
# #Person1# interviews Mr. Steven Kayne, who has just taken over and
# Ethel and #Person2# are arguing about whether they are middle-aged or
# #Person2# thinks the meal was perfect and wants to split something with #Person
# #Person1# and #Person2# are trying to make a plan
# Mr. Murray wants to get a library card. #Person2# gives him an
# #Person2# tells #Person1# about the typical 9 to 5
# #Person2# tells #Person1# how to use the washing machines
# #Person1# and #Person2# talk about their recent activities.
# Katie has arrived late several times but she has improved since #Person1#'
# #Person1# and #Person2# are planning a surprise party for grandpa
# Gian Luca Donatelli and Gina introduce themselves to each other at a
# Kathy thinks the countryside is noisy because it's the year of 17-year bird
# #Person1# helps #Person2# order a turkey sandwich, soup,
# James tells #Person1# he's almost finished packing and is waiting for the jacket
# Ted's wife is going to stay at her parents' for a few weeks. #
# #Person1# wants to go to the cinema. #Person2# suggests going
# #Person2#'s house was robbed last night and the thieves stole all #
# Jack invites Charlie to come to his house to play a new video game. Charlie agrees
# #Person2# tells #Person1# #Person3# got interested
# Alice tells #Person1# how to use the washing machines. #Person2#
# Steve's looking for a place to live because his lease runs out next month. Matthew
# Frank tells Betsy he got a promotion and invites her to his party on Saturday. Betsy

# %%
model.save_pretrained('./saved_model/')
tokenizer.save_pretrained('./saved_model/')
# Out:
# Configuration saved in ./saved_model/config.json
# Model weights saved in ./saved_model/pytorch_model.bin
# tokenizer config file saved in ./saved_model/tokenizer_config.json
# Special tokens file saved in ./saved_model/special_tokens_map.json
# ('./saved_model/tokenizer_config.json',
#  './saved_model/special_tokens_map.json',
#  './saved_model/vocab.json',
#  './saved_model/merges.txt',
#  './saved_model/added_tokens.json')

# %% [markdown]
# # **TweetSumm**

# %%
# %cd /content/TweetSumm_trained
# Out:
# /content/TweetSumm_trained

# %%
# !git clone https://github.com/PranjaliJain/TweetSumm_trained.git

# %%
from tweet_sum_processor import TweetSumProcessor

# %%
model_name = './../dialogsum_trained/saved_model/'
tokenizer = BartTokenizer.from_pretrained(model_name)
model = BartForConditionalGeneration.from_pretrained(model_name)
# Out:
# Didn't find file ./../dialogsum_trained/saved_model/added_tokens.json. We won't load it.
# loading file ./../dialogsum_trained/saved_model/vocab.json
# loading file ./../dialogsum_trained/saved_model/merges.txt
# loading file None
# loading file ./../dialogsum_trained/saved_model/special_tokens_map.json
# loading file ./../dialogsum_trained/saved_model/tokenizer_config.json
# loading configuration file ./../dialogsum_trained/saved_model/config.json
# Model config BartConfig {
#   "_name_or_path": "./saved_model/",
#   "activation_dropout": 0.1,
#   "activation_function": "gelu",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartForConditionalGeneration"
#   ],
#   "attention_dropout": 0.1,
#   "bos_token_id": 0,
#   "classif_dropout": 0.1,
#   "classifier_dropout": 0.0,
#   "d_model": 1024,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 4096,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 12,
#   "decoder_start_token_id": 2,
#   "dropout": 0.1,
#   "early_stopping": true,
#   "encoder_attention_heads": 16,
#   "encoder_ffn_dim": 4096,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 12,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "max_position_embeddings": 1024,
#   "model_type": "bart",
#   "no_repeat_ngram_size": 3,
#   "normalize_before": false,
#   "num_beams": 4,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "scale_embedding": false,
#   "task_specific_params": {
#     "summarization": {
#       "length_penalty": 1.0,
#       "max_length": 128,
#       "min_length": 12,
#       "num_beams": 4
#     },
#     "summarization_cnn": {
#       "length_penalty": 2.0,
#       "max_length": 142,
#       "min_length": 56,
#       "num_beams": 4
#     },
#     "summarization_xsum": {
#       "length_penalty": 1.0,
#       "max_length": 62,
#       "min_length": 11,
#       "num_beams": 6
#     }
#   },
#   "torch_dtype": "float32",
#   "transformers_version": "4.18.0",
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file ./../dialogsum_trained/saved_model/pytorch_model.bin
# All model checkpoint weights were used when initializing BartForConditionalGeneration.
#
# All the weights of BartForConditionalGeneration were initialized from the model checkpoint at ./../dialogsum_trained/saved_model/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BartForConditionalGeneration for predictions without further training.

# %%
# ----- Metric
metric = load_metric("rouge")

# ---- Freeze parameters

def freeze_params(model: nn.Module):
    """Set requires_grad=False for each of model.parameters()"""
    for par in model.parameters():
        par.requires_grad = False

def freeze_embeds(model):
    """Freeze token embeddings and positional embeddings for BART and PEGASUS, just token embeddings for t5."""
    model_type = model.config.model_type
    if model_type == "t5":
        freeze_params(model.shared)
        for d in [model.encoder, model.decoder]:
            freeze_params(d.embed_tokens)
    else:
        freeze_params(model.model.shared)
        for d in [model.model.encoder, model.model.decoder]:
            freeze_params(d.embed_positions)
            freeze_params(d.embed_tokens)

freeze_embeds(model)

# ----- Reading in the Dataset
raw_datasets = load_dataset('csv', data_files={'train': '/content/TweetSumm_trained/data/tweetsum_train.csv',
                                          'valid': '/content/TweetSumm_trained/data/tweetsum_valid.csv',
                                          'test': '/content/TweetSumm_trained/data/tweetsum_test.csv'})
# Out:
# Using custom data configuration default-3760b9b9fac89e08
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-3760b9b9fac89e08/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-3760b9b9fac89e08/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
max_input_length = 256
max_target_length = 128

def preprocess_function(examples):
    model_inputs = tokenizer(examples["inputs"], max_length=max_input_length, truncation=True)

    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(examples["summaries"], max_length=max_target_length, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_datasets = raw_datasets.map(preprocess_function, batched=True)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
batch_size = 1
args = Seq2SeqTrainingArguments(
    evaluation_strategy = "epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=3,
    predict_with_generate=True,
    fp16=True,
    push_to_hub=False,
    output_dir = '/content/drive/MyDrive/CIS6930_final/results/bart', 
    logging_dir = '/content/drive/MyDrive/CIS6930_final/logs/bart'
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip())) for pred in decoded_preds]
    decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) for label in decoded_labels]
    
    result = metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    # Extract a few results
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
    
    # Add mean generated length
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    
    return {k: round(v, 4) for k, v in result.items()}

# %% [markdown]
# # **NO fine-tuning on TweetSumm**

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

trainer = Seq2SeqTrainer(
    model,
    args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["valid"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# trainer.train()
# Out:
# Using amp half precision backend

# %%
# --------------------- # 
#    TEST EVALUATION    #
# --------------------- #

out = trainer.predict(tokenized_datasets["test"])
generated_summaries = []
for i in range(0, 110): 
  generated_summaries.append(tokenizer.decode(out[0][i], skip_special_tokens =  True))
ground_truth = tokenized_datasets["test"]["summaries"]
conversation = tokenized_datasets["test"]["inputs"]
# Out:
# The following columns in the test set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: inputs, summaries. If inputs, summaries are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 110
#   Batch size = 1
#     <div>
#
#       <progress value='110' max='110' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [110/110 00:39]
#     </div>

# %%
out.metrics
# Out:
# {'test_gen_len': 20.0,
#  'test_loss': 3.859863519668579,
#  'test_rouge1': 20.3368,
#  'test_rouge2': 6.4265,
#  'test_rougeL': 16.5027,
#  'test_rougeLsum': 18.4148,
#  'test_runtime': 40.5731,
#  'test_samples_per_second': 2.711,
#  'test_steps_per_second': 2.711}

# %%
P, R, F1 = score(generated_summaries, ground_truth, lang="en", verbose=True)

# %%
print(f"System level F1 score: {F1.mean():.3f}")
print(f"System level precision score: {P.mean():.3f}")
print(f"System level recall score: {R.mean():.3f}")

# %% [markdown]
# # **Fine-tuning on TweetSumm**

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

trainer = Seq2SeqTrainer(
    model,
    args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["valid"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
trainer.train()
# Out:
# Using amp half precision backend
# The following columns in the training set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: inputs, summaries. If inputs, summaries are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 869
#   Num Epochs = 3
#   Instantaneous batch size per device = 1
#   Total train batch size (w. parallel, distributed & accumulation) = 1
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2607
#     <div>
#
#       <progress value='2607' max='2607' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2607/2607 17:06, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.379300</td>
#       <td>2.108410</td>
#       <td>32.422400</td>
#       <td>14.249700</td>
#       <td>27.878600</td>
#       <td>30.325700</td>
#       <td>20.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.732400</td>
#       <td>2.064653</td>
#       <td>34.135200</td>
#       <td>15.376200</td>
#       <td>29.347500</td>
#       <td>32.141700</td>
#       <td>20.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.416900</td>
#       <td>2.076144</td>
#       <td>36.076100</td>
#       <td>16.923800</td>
#       <td>31.533700</td>
#       <td>34.217600</td>
#       <td>20.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-500
# Configuration saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-500/config.json
# Model weights saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-500/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: inputs, summaries. If inputs, summaries are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 108
#   Batch size = 1
# Saving model checkpoint to /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-1000
# Configuration saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-1000/config.json
# Model weights saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-1000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-1500
# Configuration saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-1500/config.json
# Model weights saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-1500/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: inputs, summaries. If inputs, summaries are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 108
#   Batch size = 1
# Saving model checkpoint to /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-2000
# Configuration saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-2000/config.json
# Model weights saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-2000/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-2500
# Configuration saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-2500/config.json
# Model weights saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-2500/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/CIS6930_final/results/bart/checkpoint-1000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: inputs, summaries. If inputs, summaries are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 108
#   Batch size = 1
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=2607, training_loss=1.798732568808886, metrics={'train_runtime': 1026.9638, 'train_samples_per_second': 2.539, 'train_steps_per_second': 2.539, 'total_flos': 1277508162945024.0, 'train_loss': 1.798732568808886, 'epoch': 3.0})

# %%
# --------------------- # 
#    TEST EVALUATION    #
# --------------------- #

out = trainer.predict(tokenized_datasets["test"])
generated_summaries = []
for i in range(0, 110): 
  generated_summaries.append(tokenizer.decode(out[0][i], skip_special_tokens =  True))
ground_truth = tokenized_datasets["test"]["summaries"]
conversation = tokenized_datasets["test"]["inputs"]
# Out:
# The following columns in the test set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: inputs, summaries. If inputs, summaries are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 110
#   Batch size = 1
#     <div>
#
#       <progress value='110' max='110' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [110/110 00:39]
#     </div>

# %%
out.metrics
# Out:
# {'test_gen_len': 20.0,
#  'test_loss': 2.0977628231048584,
#  'test_rouge1': 34.1796,
#  'test_rouge2': 14.9658,
#  'test_rougeL': 30.0137,
#  'test_rougeLsum': 32.0041,
#  'test_runtime': 40.3824,
#  'test_samples_per_second': 2.724,
#  'test_steps_per_second': 2.724}

# %%
P, R, F1 = score(generated_summaries, ground_truth, lang="en", verbose=True)

# %%
print(f"System level F1 score: {F1.mean():.3f}")
print(f"System level precision score: {P.mean():.3f}")
print(f"System level recall score: {R.mean():.3f}")
